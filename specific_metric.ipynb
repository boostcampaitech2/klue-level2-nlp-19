# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
import mglearn
import matplotlib.pyplot as plt

# %% [markdown]
# # Valid1

# %%
save_name = 'submission_bert_metric_valid2.0'
save_path = os.path.join("../dataset/metric", f'{save_name}.csv')
dataformetric1 = pd.read_csv(save_path)
dataformetric1
# Out:
#       output  target
# 0          0       0
# 1          4       4
# 2         15      15
# 3          1       1
# 4          0       0
# ...      ...     ...
# 3242       0       0
# 3243       0       0
# 3244       1       1
# 3245       1       1
# 3246       1       1
#
# [3247 rows x 2 columns]

# %%
print(classification_report(dataformetric1['output'], dataformetric1['target']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76       906
#            1       0.95      0.94      0.95       433
#            2       0.57      0.60      0.59        40
#            3       0.74      0.82      0.78        34
#            4       0.90      0.90      0.90       209
#            5       0.91      0.86      0.89       139
#            6       0.87      0.85      0.86       368
#            7       0.76      0.76      0.76       119
#            8       0.50      0.50      0.50        14
#            9       0.60      1.00      0.75         3
#           10       0.73      0.79      0.76        28
#           11       0.53      0.32      0.40        31
#           12       0.87      0.91      0.89        96
#           13       0.58      0.58      0.58        19
#           14       0.55      0.62      0.58        47
#           15       0.78      0.76      0.77       126
# ...

# %% [markdown]
# print(Confusion_matrix_fromfile(dataformetric2['output'], dataformetric2['target']))

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 12))
scores_image = mglearn.tools.heatmap(confusion_matrix(dataformetric1['output'], dataformetric1['target']),
                                    xlabel='pred_labels', ylabel='target_labels', xticklabels=np.arange(30),
                                    yticklabels=np.arange(30), cmap=plt.cm.gray_r, fmt="%d")
plt.title('Confusion Matrix')
# axes[0].gca().invert_yaxis()
# plt.show()
plt.gca().invert_yaxis()
