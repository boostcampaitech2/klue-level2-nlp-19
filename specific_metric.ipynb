# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
import mglearn
import matplotlib.pyplot as plt

# %% [markdown]
# # Valid1

# %%
save_name = 'submission_bert_metric_valid1'
save_path = os.path.join("../dataset/metric", f'{save_name}.csv')
dataformetric1 = pd.read_csv(save_path)
dataformetric1
# Out:
#       output  target
# 0         20       0
# 1          4       4
# 2         15      15
# 3          1       1
# 4          0       0
# ...      ...     ...
# 3242       0       0
# 3243       0       0
# 3244       1       1
# 3245       1       1
# 3246       1       1
#
# [3247 rows x 2 columns]

# %%
print(classification_report(dataformetric1['output'], dataformetric1['target']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.60      1099
#            1       0.83      0.89      0.86       402
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.79      0.57      0.66       291
#            5       0.61      0.61      0.61       133
#            6       0.60      0.65      0.62       332
#            7       0.22      0.44      0.29        59
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.68      0.56      0.62       121
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.69      0.49      0.57       174
#           16       0.00      0.00      0.00         0
#           17       0.60      0.41      0.49       116
#           18       0.49      0.56      0.52        39
#           19       0.00      0.00      0.00         0
#           20       0.62      0.43      0.51       267
#           21       0.31      0.31      0.31        52
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           24       0.64      0.79      0.71        34
#           25       0.97      0.86      0.91       128
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#
#     accuracy                           0.60      3247
#    macro avg       0.29      0.27      0.28      3247
# weighted avg       0.67      0.60      0.63      3247
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# print(Confusion_matrix_fromfile(dataformetric2['output'], dataformetric2['target']))

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 12))
scores_image = mglearn.tools.heatmap(confusion_matrix(dataformetric1['output'], dataformetric1['target']),
                                    xlabel='pred_labels', ylabel='target_labels', xticklabels=np.arange(30),
                                    yticklabels=np.arange(30), cmap=plt.cm.gray_r, fmt="%d")
plt.title('Confusion Matrix')
# axes[0].gca().invert_yaxis()
# plt.show()
plt.gca().invert_yaxis()
